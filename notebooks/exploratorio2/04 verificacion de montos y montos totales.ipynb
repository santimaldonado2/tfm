# %%
import pandas as pd
import numpy as np
from plotnine import *

# %matplotlib inline

# %%
data = pd.read_csv("../../data/processed/expensas_full.csv",
                  dtype = {
                                "expensa_id": "object",
                                "unidad_id": "object",
                                "propietario_id": "object",
                                "inquilino_id": "object",
                                "consorcio_id": "object",
                                "consorcio_usa_fondo": "bool",
                                "consorcio_solo_muestra_cat": "bool",
                                "unidad_tipo":"object",
                                "expensa_concepto": "object",
                                "expensa_mes":"object",
                                "expensa_anio":"object",
                                "unidad_propietario":"object",
                                "unidad_inquilino":"object",
                                "expensa_version":"object"
                            })

# %%
data.shape
# Out:
# (226976, 32)

# %%
data.describe()
# Out:
#        consorcio_interes_primer_vencimiento  \
# count                         226976.000000
# mean                               3.462958
# std                                2.656833
# min                                0.000000
# 25%                                2.000000
# 50%                                3.000000
# 75%                                5.000000
# max                               35.000000
#
#        consorcio_interes_segundo_vencimiento  unidad_metros  expensa_monto  \
# count                          226976.000000  226976.000000  226976.000000
# mean                                5.562751      16.945655    1935.362005
# std                                 3.074049     258.259925    1844.065133
# min                                 0.000000       0.000000       1.000000
# 25%                                 4.000000       0.540000     810.000000
# 50%                                 5.000000       1.590000    1555.000000
# ...

# %%
data.loc[:, ["consorcio_id", "consorcio_nombre", "consorcio_fecha_creacion","expensa_mes", "expensa_anio", "expensa_proporcion","expensa_monto", "expensa_monto_parcial", "expensa_monto_total","expensa_primer_vencimiento", "pago_fecha", "pago_monto"]].sort_values("ex")
# Out:
#        consorcio_id                     consorcio_nombre  \
# 86598          1461                    Queen Mary Office
# 86290          1461                    Queen Mary Office
# 86324          1461                    Queen Mary Office
# 86358          1461                    Queen Mary Office
# 86392          1461                    Queen Mary Office
# 86426          1461                    Queen Mary Office
# 86461          1461                    Queen Mary Office
# 86496          1461                    Queen Mary Office
# 86530          1461                    Queen Mary Office
# 86564          1461                    Queen Mary Office
# 188811         1696              Mural I Extraordinarias
# 188810         1696              Mural I Extraordinarias
# 188803         1696              Mural I Extraordinarias
# 188808         1696              Mural I Extraordinarias
# 188807         1696              Mural I Extraordinarias
# ...

# %%
data.loc[:, ["consorcio_id", "consorcio_nombre", "consorcio_fecha_creacion", "unidad_denominacion", "unidad_tipo","expensa_mes", "expensa_anio", "expensa_proporcion","expensa_monto", "expensa_monto_parcial", "expensa_monto_total","expensa_primer_vencimiento", "pago_fecha", "pago_monto", "pago_metodo"]].sort_values(["expensa_monto"])[:50]
# Out:
#        consorcio_id           consorcio_nombre consorcio_fecha_creacion  \
# 218170         1851         CONSORCIO DEMOR IV      2018-09-06 15:09:27
# 218171         1851         CONSORCIO DEMOR IV      2018-09-06 15:09:27
# 218174         1851         CONSORCIO DEMOR IV      2018-09-06 15:09:27
# 218173         1851         CONSORCIO DEMOR IV      2018-09-06 15:09:27
# 218172         1851         CONSORCIO DEMOR IV      2018-09-06 15:09:27
# 218175         1851         CONSORCIO DEMOR IV      2018-09-06 15:09:27
# 219074         1859  GRUPO NOVA EXTRAORDINARIO      2018-09-10 17:10:25
# 28382           733       Impuestos Metropolis      2013-09-02 10:10:16
# 28358           733       Impuestos Metropolis      2013-09-02 10:10:16
# 28454           733       Impuestos Metropolis      2013-09-02 10:10:16
# 28430           733       Impuestos Metropolis      2013-09-02 10:10:16
# 28574           733       Impuestos Metropolis      2013-09-02 10:10:16
# ...
