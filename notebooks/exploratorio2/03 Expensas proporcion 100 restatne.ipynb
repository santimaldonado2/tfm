# %%
import pandas as pd
import numpy as np
from plotnine import *

# %matplotlib inline

# %%
data = pd.read_csv("../../data/processed/expensas_full.csv",
                  dtype = {
                                "expensa_id": "object",
                                "unidad_id": "object",
                                "propietario_id": "object",
                                "inquilino_id": "object",
                                "consorcio_id": "object",
                                "consorcio_usa_fondo": "bool",
                                "consorcio_solo_muestra_cat": "bool",
                                "unidad_tipo":"object",
                                "expensa_concepto": "object",
                                "expensa_mes":"object",
                                "expensa_anio":"object",
                                "unidad_propietario":"object",
                                "unidad_inquilino":"object",
                                "expensa_version":"object"
                            })

# %%
data.shape
# Out:
# (266376, 32)

# %%
data.describe()
# Out:
#        consorcio_interes_primer_vencimiento  \
# count                         266376.000000
# mean                               3.585034
# std                                3.024783
# min                                0.000000
# 25%                                2.000000
# 50%                                3.000000
# 75%                                5.000000
# max                               35.000000
#
#        consorcio_interes_segundo_vencimiento  unidad_metros  expensa_monto  \
# count                          266376.000000  266376.000000  266376.000000
# mean                                5.496764      17.168548    1905.930689
# std                                 3.149914     257.928729    1941.339207
# min                                 0.000000       0.000000   -3091.000000
# 25%                                 4.000000       0.540000     764.895000
# 50%                                 5.000000       1.493000    1500.000000
# ...

# %%
data.loc[data.expensa_proporcion >90,["consorcio_id", "consorcio_nombre", "consorcio_fecha_creacion","expensa_mes", "expensa_anio", "expensa_proporcion","expensa_monto", "expensa_monto_total", "expensa_primer_vencimiento", "pago_fecha", "pago_monto"]].sort_values("expensa_proporcion")
# Out:
#        consorcio_id                               consorcio_nombre  \
# 254296         1887                              EDIFICIO LIMA 135
# 265200         2053      Consorcio de Propietarios Marco Polo 5345
# 97666          1431                                EDIFICIO ARVIAL
# 23073           533                              Paso de los Andes
# 259233         1981              LISANDRO DE LA TORRE Y 9 DE JULIO
# 259234         1981              LISANDRO DE LA TORRE Y 9 DE JULIO
# 259235         1981              LISANDRO DE LA TORRE Y 9 DE JULIO
# 259236         1981              LISANDRO DE LA TORRE Y 9 DE JULIO
# 259237         1981              LISANDRO DE LA TORRE Y 9 DE JULIO
# 259238         1981              LISANDRO DE LA TORRE Y 9 DE JULIO
# 259239         1981              LISANDRO DE LA TORRE Y 9 DE JULIO
# 259240         1981              LISANDRO DE LA TORRE Y 9 DE JULIO
# 259249         1982                              CATAMARCA 3528/30
# ...

# %%
data = data.loc[data.expensa_proporcion<=90]

# %%
data = data.loc[(data.expensa_monto > 0) & (data.expensa_monto_total > 0)]

# %%
data.shape
# Out:
# (263506, 32)

# %%
data.describe()
# Out:
#        consorcio_interes_primer_vencimiento  \
# count                         263506.000000
# mean                               3.579799
# std                                2.965644
# min                                0.000000
# 25%                                2.000000
# 50%                                3.000000
# 75%                                5.000000
# max                               35.000000
#
#        consorcio_interes_segundo_vencimiento  unidad_metros  expensa_monto  \
# count                          263506.000000  263506.000000  263506.000000
# mean                                5.490869      17.237774    1906.786630
# std                                 3.107470     259.312196    1859.214853
# min                                 0.000000       0.000000       1.000000
# 25%                                 4.000000       0.546000     774.917500
# 50%                                 5.000000       1.493000    1500.000000
# ...

# %%
pagos_0 = data.loc[data.pago_monto <= 0,["consorcio_id", "consorcio_nombre", "unidad_denominacion","consorcio_fecha_creacion","expensa_mes", "expensa_anio", "expensa_proporcion","expensa_monto", "expensa_monto_total", "expensa_monto_parcial","expensa_primer_vencimiento", "pago_fecha", "pago_monto"]].sort_values("expensa_monto_parcial")

# %%
pagos_0.groupby("pago_fecha").count().sort_values("consorcio_id", ascending =False)
# Out:
#             consorcio_id  consorcio_nombre  unidad_denominacion  \
# pago_fecha
# 2016-06-29            16                16                   16
# 2018-02-14            12                12                   12
# 2018-06-29             9                 9                    9
# 2019-02-06             5                 5                    5
# 2016-05-27             5                 5                    5
# 2018-06-27             5                 5                    5
# 2018-06-12             5                 5                    5
# 2017-10-18             4                 4                    4
# 2018-10-04             4                 4                    4
# 2018-07-03             4                 4                    4
# 2016-01-29             3                 3                    3
# 2018-02-27             3                 3                    3
# 2017-12-01             3                 3                    3
# ...
