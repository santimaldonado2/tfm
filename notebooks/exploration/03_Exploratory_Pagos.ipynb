# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
pagos = pd.read_csv("../../data/interim/pagos.csv")
#expensas = pd.read_csv("../../data/interim/expensas.csv")
#unidades = pd.read_csv("../../data/interim/unidades.csv")

# %% [markdown]
# ## Pagos

# %%
pagos.shape
# Out:
# (299354, 4)

# %%
pagos.columns
# Out:
# Index(['fecha_pago', 'monto_pago', 'expensa_id', 'metodo_pago'], dtype='object')

# %%
pagos.dtypes
# Out:
# fecha_pago      object
# monto_pago     float64
# expensa_id       int64
# metodo_pago     object
# dtype: object

# %% [markdown]
# Aqui podemos observar que los tipos no son correctos, cambiamos la columna de expensa_id como string, para que no sacar métricas numericas innecesarias y configuramos la columna de fecha ocmo datetime

# %%
pagos.expensa_id = pagos.expensa_id.map(str)
pagos.fecha_pago = pd.to_datetime(pagos.fecha_pago)

# %%
pagos.dtypes
# Out:
# fecha_pago     datetime64[ns]
# monto_pago            float64
# expensa_id             object
# metodo_pago            object
# dtype: object

# %%
pagos = pagos.loc[(pagos.fecha_pago >= '2013-01-01') & (pagos.fecha_pago < '2019-01-01'),:]

# %%
pagos.shape
# Out:
# (255488, 4)

# %%
pagos["day"] = pagos.fecha_pago.dt.day
pagos["dayofweek"] = pagos.fecha_pago.dt.dayofweek
days = ["Lunes", "Martes", "Miercoles", "Jueves", "Viernes", "Sabado", "Domingo"]
pagos["day_name"] =  pagos.dayofweek.map(lambda number: days[int(number)])
pagos["month"] = pagos.fecha_pago.dt.month

# %% [markdown]
# ### Monto

# %%
pagos.describe()
# Out:
#          monto_pago            day      dayofweek          month
# count  2.554880e+05  255488.000000  255488.000000  255488.000000
# mean   1.717503e+03      12.109543       2.205219       7.350533
# std    3.380789e+03       7.451763       1.572547       3.386680
# min    1.000000e-02       1.000000       0.000000       1.000000
# 25%    5.351000e+02       7.000000       1.000000       5.000000
# 50%    1.272980e+03      10.000000       2.000000       8.000000
# 75%    2.335980e+03      16.000000       3.000000      10.000000
# max    1.003318e+06      31.000000       6.000000      12.000000

# %%
plt.title("Distribución del monto de pago")
sns.distplot(pagos.monto_pago)

# %%
plt.title("BoxPlot del monto de pago")
sns.boxenplot(pagos.monto_pago)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Por lo que se puede ver, hay pagos que son muy grandes y que deforman la distribución. Hay que revisar que hacer con ellos, pueden corresponder a expensas que sean para cancelación de deuda, las cuales no seran tenidas en cuenta. Por el momento lo filtraremos para poder analizar un poco mejor la distribución real de los datos

# %%
pagos_aux = pagos.loc[pagos.monto_pago < 10000,:]

# %%
plt.title("Distribución del monto de pago")
sns.distplot(pagos_aux.monto_pago)

# %%
plt.title("BoxPlot del monto de pago")
sns.boxplot(pagos_aux.monto_pago)

# %% [markdown]
# Hay que tener en cuenta que estas medidas no son muy representativas, dada la inflación en Argentina. Es decir cada año los pagos son mas y mas caros

# %% [markdown]
# ### Metodos de pago

# %%
plt.figure(figsize=(16,7))
plt.title("Cantidad de Pagos según Metodo de Pago")
sns.barplot(data=pagos_aux.groupby(by="metodo_pago").count().reset_index().sort_values(by="expensa_id"), x="expensa_id", y="metodo_pago")

# %%
grid = sns.FacetGrid(pagos_aux, col="metodo_pago", col_wrap = 4)
grid.map(sns.distplot, "monto_pago")
plt.title("Distribución dle monto de pago segun metodo de pago")
# Out:
# Text(0.5, 1.0, 'Distribución dle monto de pago segun metodo de pago')

# %% [markdown]
# Los meotdos de pagos **Nota de crédito** y **Saldo a favor** son mecanismos que se utilizan para saldar deudas con las unidades que se generan automaticamente, por lo que no deberian tener influencia directa en la mora

# %%
plt.figure(figsize=(16,9))
plt.title("BoxPlot Dia de pago Segun Metodo utilizado")
sns.boxplot(data=pagos_aux, x="metodo_pago" , y="day")

# %% [markdown]
# Interesante como sabiendo el metodo de pago se puede conseguir mayor precisión.

# %% [markdown]
# ### Fecha

# %%
pagos_timeline = pagos[["fecha_pago", "monto_pago"]]
pagos_cantidad_fecha = pagos_timeline.groupby("fecha_pago").count().reset_index()
pagos_suma_fecha = pagos_timeline.groupby("fecha_pago").sum().reset_index()

# %%
def plot_timeline_complete(pagos, title):
    timeline = np.arange('2013-01-01', '2018-12-31', dtype='datetime64[D]')
    pagos_complete = pd.DataFrame((timeline,np.zeros(len(timeline))))
    pagos_complete = pagos_complete.T
    pagos_complete.columns = ["fecha_pago", "monto"]
    pagos_complete.fecha_pago = pd.to_datetime(pagos_complete.fecha_pago, format='%Y-%m-%d')

    pagos_complete = pagos_complete.merge(pagos, on="fecha_pago", how="left")
    pagos_complete = pagos_complete.fillna(0)
    pagos_complete["agregacion"] = pagos_complete.monto + pagos_complete.monto_pago
    pagos_complete = pagos_complete[["fecha_pago", "agregacion"]]

    plt.figure(figsize=(16,5))
    plt.plot(pagos_complete.fecha_pago, pagos_complete.agregacion)
    plt.title(title)

# %%
plot_timeline_complete(pagos_cantidad_fecha, "Cantidad de Pagos Por Día")
# Out:
# c:\users\smaldonado\documents\tfm\venv\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
pagos_cantidad_fecha.loc[(pagos_cantidad_fecha.fecha_pago >= '2014-11-01') & (pagos_cantidad_fecha.fecha_pago <= '2014-11-30') ,:]
# Out:
#     fecha_pago  monto_pago
# 155 2014-11-03          14
# 156 2014-11-04          18
# 157 2014-11-05         464
# 158 2014-11-06         114
# 159 2014-11-07          59
# 160 2014-11-08          11
# 161 2014-11-10         140
# 162 2014-11-11          23
# 163 2014-11-12          48
# 164 2014-11-13          30
# 165 2014-11-14          27
# 166 2014-11-15           1
# 167 2014-11-17           8
# 168 2014-11-18          18
# 169 2014-11-19           9
# 170 2014-11-20          13
# 171 2014-11-21           7
# 172 2014-11-22           2
# 173 2014-11-23           1
# 174 2014-11-24           1
# 175 2014-11-25          15
# 176 2014-11-27          15
# 177 2014-11-28          16

# %% [markdown]
# El **2014-11-05** es una fecha atipica, para analizar un poco

# %%
pagos_cantidad_fecha.loc[(pagos_cantidad_fecha.fecha_pago >= '2016-09-27') & (pagos_cantidad_fecha.fecha_pago <= '2016-10-2') ,:]
# Out:
#     fecha_pago  monto_pago
# 784 2016-09-27          36
# 785 2016-09-28          45
# 786 2016-09-29         753
# 787 2016-09-30          59
# 788 2016-10-01           7
# 789 2016-10-02           1

# %% [markdown]
# El **2016-09-29** es una fecha atipica, para analizar un poco

# %%
plot_timeline_complete(pagos_suma_fecha, "Monto Pagado Por Dia")

# %% [markdown]
# Habría que revisar que paso en 2015 que hay dos fechas que se registraron muchos ingresos, de una forma atipica

# %%
plt.figure(figsize=(16,5))
sns.barplot(data=pagos_aux.groupby(by="day").count().reset_index().sort_values(by="expensa_id"), y="expensa_id", x="day")
plt.title("Cantidad de Pagos Segun Dia del Mes")
# Out:
# Text(0.5, 1.0, 'Cantidad de Pagos Segun Dia del Mes')

# %%
plt.figure(figsize=(16,5))
sns.distplot(pagos_aux.day, bins=31)
plt.title("Distribución de Pagos Segun Dia del Mes")
# Out:
# Text(0.5, 1.0, 'Distribución de Pagos Segun Dia del Mes')

# %%
plt.figure(figsize=(16,5))
sns.barplot(data=pagos_aux.groupby(by=["dayofweek","day_name"]).count().reset_index(), y="expensa_id", x="day_name")
plt.title("Cantidad de Pagos Segun Dia de la Semana")
# Out:
# Text(0.5, 1.0, 'Cantidad de Pagos Segun Dia de la Semana')

# %%
plt.figure(figsize=(20,8))
sns.heatmap(pagos_aux.groupby(["day","dayofweek"]).count().reset_index().pivot("dayofweek","day","monto_pago"), annot=True, fmt="d", cmap="Blues")
plt.title("HeatMap de Cantidad de Pagos segun Dia de la semana y del mes")
# Out:
# Text(0.5, 1.0, 'HeatMap de Cantidad de Pagos segun Dia de la semana y del mes')

# %%
pagos_aux.groupby(["day","day_name","dayofweek"]).count().reset_index()[["day_name","day","monto_pago"]].sort_values("monto_pago", ascending=False).head(10)
# Out:
#      day_name  day  monto_pago
# 65      Lunes   10        6026
# 66     Martes   10        5320
# 62    Viernes    9        4641
# 67  Miercoles   10        4438
# 48    Viernes    7        4009
# 69    Viernes   10        3781
# 46  Miercoles    7        3726
# 32  Miercoles    5        3577
# 36     Jueves    6        3530
# 50     Jueves    8        3496

# %%
plt.figure(figsize=(16,5))
sns.barplot(data=pagos_aux.groupby(by="month").count().reset_index().sort_values(by="expensa_id"), y="expensa_id", x="month")
plt.title("Cantidad de Pagos por Mes")
# Out:
# Text(0.5, 1.0, 'Cantidad de Pagos por Mes')

# %% [markdown]
# A primera vista es un poco extraño el grafico, ya que las expensas se pagan todos los meses y a priori todos los meses deberian tener la misma cantidad de pagos, pero este gráfico refleja la tasa de crecimiento de la startup que es del 9% mensual.

# %%
plt.figure(figsize=(20,8))
sns.heatmap(pagos_aux.groupby(["day","month"]).count().reset_index().pivot("month","day","monto_pago"), annot=True, fmt=".0f",cmap="Blues")
plt.title("HeatMap de Cantidad de Pagos por mes según dia del mes")
# Out:
# Text(0.5, 1.0, 'HeatMap de Cantidad de Pagos por mes según dia del mes')

# %% [markdown]
# En este caso se pueden ver la influencia de laguns feriados en la cantidad de pagos, por ejemplo el 8 de Diciembre o el 9 de Julio

# 211012 2014-11-05       71.88       7952     Transferencia    5          2
# 170569 2014-11-05     1086.96       8203  Pago Mis Cuentas    5          2
# 88113  2014-11-05      515.38       8239          Rapipago    5          2
# 88112  2014-11-05      442.37       8242          Rapipago    5          2
# 88114  2014-11-05      816.95       8261          Rapipago    5          2
# 88110  2014-11-05      434.54       8350          Rapipago    5          2
# 88111  2014-11-05      159.92       8366          Rapipago    5          2
# 88137  2014-11-05     1214.29       8369          Rapipago    5          2
# 88134  2014-11-05     1214.29       8373          Rapipago    5          2
# 88138  2014-11-05     1214.29       8376          Rapipago    5          2
# 88107  2014-11-05     1214.29       8378          Rapipago    5          2
# 88136  2014-11-05     1256.79       8385          Rapipago    5          2
# 88135  2014-11-05     1256.79       8386          Rapipago    5          2
#
#          day_name
# 351     Miercoles
# 357     Miercoles
# 363     Miercoles
# 375     Miercoles
# 345     Miercoles
# 369     Miercoles
# 399     Miercoles
# 405     Miercoles
# 411     Miercoles
# 387     Miercoles
# 381     Miercoles
# 393     Miercoles
# 433     Miercoles
# 431     Miercoles
# 425     Miercoles
# 427     Miercoles
# 429     Miercoles
# 415     Miercoles
# 417     Miercoles
# 419     Miercoles
# 421     Miercoles
# 423     Miercoles
# 352     Miercoles
# 358     Miercoles
# 364     Miercoles
# 376     Miercoles
# 346     Miercoles
# 370     Miercoles
# 400     Miercoles
# 406     Miercoles
# ...           ...
# 88127   Miercoles
# 88130   Miercoles
# 88118   Miercoles
# 88115   Miercoles
# 88119   Miercoles
# 88129   Miercoles
# 88128   Miercoles
# 88132   Miercoles
# 88122   Miercoles
# 88108   Miercoles
# 88109   Miercoles
# 88105   Miercoles
# 88106   Miercoles
# 781     Miercoles
# 772     Miercoles
# 88133   Miercoles
# 774     Miercoles
# 211012  Miercoles
# 170569  Miercoles
# 88113   Miercoles
# 88112   Miercoles
# 88114   Miercoles
# 88110   Miercoles
# 88111   Miercoles
# 88137   Miercoles
# 88134   Miercoles
# 88138   Miercoles
# 88107   Miercoles
# 88136   Miercoles
# 88135   Miercoles
#
# [463 rows x 7 columns]

# %% [markdown]
# Algo extraño pero por ahora no explicable

# %% [markdown]
# ### que hay el 2016-09-29

# %%
pagos_aux.loc[pagos_aux.fecha_pago == "2016-09-29",:]
# Out:
#        fecha_pago  monto_pago expensa_id       metodo_pago  day  dayofweek  \
# 15765  2016-09-29     2696.12      67898          Efectivo   29          3
# 15766  2016-09-29     3671.02      67938          Efectivo   29          3
# 15767  2016-09-29      416.86      68096          Efectivo   29          3
# 15768  2016-09-29     1452.28      67930          Efectivo   29          3
# 15769  2016-09-29     1324.31      72125          Efectivo   29          3
# 15770  2016-09-29     2696.12      67769          Efectivo   29          3
# 15771  2016-09-29     2458.55      71964          Efectivo   29          3
# 15772  2016-09-29      416.86      67986          Efectivo   29          3
# 15773  2016-09-29      380.12      72181          Efectivo   29          3
# 15774  2016-09-29      416.86      68025          Efectivo   29          3
# 15775  2016-09-29      380.12      72220          Efectivo   29          3
# 15767    Jueves
# 15768    Jueves
# 15769    Jueves
# 15770    Jueves
# 15771    Jueves
# 15772    Jueves
# 15773    Jueves
# 15774    Jueves
# 15775    Jueves
# 15776    Jueves
# 15777    Jueves
# 15778    Jueves
# 15779    Jueves
# 15780    Jueves
# 15781    Jueves
# 15782    Jueves
# 15783    Jueves
# 15784    Jueves
# 15785    Jueves
# 15786    Jueves
# 15787    Jueves
# 15788    Jueves
# 15789    Jueves
# 15790    Jueves
# 15791    Jueves
# 15792    Jueves
# 15793    Jueves
# 15794    Jueves
# ...         ...
# 16489    Jueves
# 16490    Jueves
# 16491    Jueves
# 16492    Jueves
# 16493    Jueves
# 16494    Jueves
# 16495    Jueves
# 16496    Jueves
# 16497    Jueves
# 16498    Jueves
# 16499    Jueves
# 16500    Jueves
# 16501    Jueves
# 16502    Jueves
# 16503    Jueves
# 16504    Jueves
# 16505    Jueves
# 16506    Jueves
# 16507    Jueves
# 18198    Jueves
# 103373   Jueves
# 103374   Jueves
# 103375   Jueves
# 103376   Jueves
# 103377   Jueves
# 173231   Jueves
# 231482   Jueves
# 231483   Jueves
# 231484   Jueves
# 231485   Jueves
#
# [753 rows x 7 columns]

# %% [markdown]
# ### Feriados

# %%
feriados = [
    #2013
    '2013-01-01',
    '2013-01-31',
    '2013-02-11',
    '2013-02-12',
    '2013-02-20',
    '2013-03-28',
    '2013-03-29',
    '2013-04-01',
    '2013-04-02',
    '2013-05-01',
    '2013-06-20',
    '2013-06-21',
    '2013-07-09',
    '2013-08-19',
    '2013-10-14',
    '2013-11-25',
    '2013-12-25',
    #2014
    '2014-01-01',
    '2014-03-03',
    '2014-03-04',
    '2014-03-24',
    '2014-04-02',
    '2014-04-18',
    '2014-05-01',    
    '2014-05-02',
    '2014-06-20',
    '2014-07-09',
    '2014-08-18',
    '2014-10-13',
    '2014-11-24',
    '2014-12-25',    
    '2014-12-26',
    #2015
    '2015-01-01',
    '2015-02-16',
    '2015-02-17',
    '2015-03-23',
    '2015-03-24',
    '2015-04-02',
    '2015-04-03',
    '2015-05-01',    
    '2015-05-25',
    '2015-06-20',
    '2015-07-09',
    '2015-08-17',
    '2015-10-12',
    '2015-11-23',    
    '2015-12-07',   
    '2015-12-08',
    '2015-12-25',
    #2016
    '2016-01-01',
    '2016-02-08',
    '2016-02-09',
    '2016-03-24',
    '2016-03-25',
    '2016-04-02',
    '2016-05-01',
    '2016-05-25',
    '2016-06-20',
    '2016-07-08',
    '2016-07-09',
    '2016-08-15',
    '2016-10-12',
    '2016-11-28',
    '2016-12-08',
    '2016-12-09',
    '2016-12-25',
    #2017
    '2017-01-01',
    '2017-02-27',
    '2017-02-28',
    '2017-03-27',
    '2017-04-02',
    '2017-04-14',
    '2017-05-01',
    '2017-05-25',
    '2017-06-17',
    '2017-06-19',
    '2017-07-09',
    '2017-08-21',
    '2017-10-09',
    '2017-11-27',
    '2017-12-08',
    '2017-12-25',
    #2018
    '2018-01-01',
    '2018-02-12',
    '2018-02-13',
    '2018-03-24',
    '2018-03-30',
    '2018-04-02',
    '2018-05-01',
    '2018-05-25',
    '2018-06-20',
    '2018-07-09',
    '2018-08-20',
    '2018-10-15',
    '2018-11-19',
    '2018-12-08',
    '2018-12-25'    
]

# %%
pagos_aux["feriados"] = pagos_aux.fecha_pago.dt.date.map(lambda x: str(x) in feriados)
# Out:
# c:\users\smaldonado\documents\tfm\venv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pagos_aux.loc[pagos_aux.feriados & (pagos_aux.day <= 10),:]
# Out:
#        fecha_pago  monto_pago expensa_id      metodo_pago  day  dayofweek  \
# 4841   2015-07-09      715.22      24541         Efectivo    9          3
# 4842   2015-07-09      700.93      24542         Efectivo    9          3
# 4843   2015-07-09      779.93      24543         Efectivo    9          3
# 4844   2015-07-09      715.22      24544         Efectivo    9          3
# 4845   2015-07-09      700.93      24545         Efectivo    9          3
# 4846   2015-07-09      779.93      24546         Efectivo    9          3
# 4847   2015-07-09      400.05      24538         Efectivo    9          3
# 4848   2015-07-09     1416.15      24539         Efectivo    9          3
# 4869   2015-07-09     1048.66      25084         Efectivo    9          3
# 4870   2015-07-09      970.48      25090         Efectivo    9          3
# 7400   2015-12-07     1003.35      34260         Efectivo    7          0
# 7539   2015-12-08     1173.89      35109         Efectivo    8          1
# 7677   2015-12-07     1106.36      33235         Efectivo    7          0
# 7678   2015-12-07     1320.32      33230         Efectivo    7          0
# 7679   2015-12-07     1106.36      33226         Efectivo    7          0
# 7680   2015-12-07      892.39      33216         Efectivo    7          0
# 7681   2015-12-07      213.97      33215         Efectivo    7          0
# 7682   2015-12-07      323.56      33214         Efectivo    7          0
# 7683   2015-12-07      339.21      33181         Efectivo    7          0
# 7684   2015-12-07     1304.67      33178         Efectivo    7          0
# 7685   2015-12-07     1320.32      33239         Efectivo    7          0
# 8743   2016-02-08     1729.95      39551         Efectivo    8          0
# 8744   2016-02-08      317.33      39769         Efectivo    8          0
# 8774   2016-02-08     1179.00      41729         Efectivo    8          0
# 10296  2016-04-02      874.16      43330         Efectivo    2          5
# 10297  2016-04-02      978.08      33132         Efectivo    2          5
# 10298  2016-04-02      474.62      33195         Efectivo    2          5
# 10299  2016-04-02      902.79      37875         Efectivo    2          5
# 10300  2016-04-02      587.00      40220         Efectivo    2          5
# 10301  2016-04-02      803.52      43312         Efectivo    2          5
# ...           ...         ...        ...              ...  ...        ...
# 285022 2018-12-08     2739.88     381205       Link Pagos    8          5
# 285023 2018-12-08     2739.88     381266       Link Pagos    8          5
# 285024 2018-12-08     2739.88     381267       Link Pagos    8          5
# 285025 2018-12-08     3627.63     360665       Link Pagos    8          5
# 285026 2018-12-08     3000.00     379726       Link Pagos    8          5
# 285028 2018-12-08     1187.00     378534       Link Pagos    8          5
# 285029 2018-12-08      671.00     367985       Link Pagos    8          5
# 285030 2018-12-08     2066.00     369973       Link Pagos    8          5
# 285041 2018-12-08      952.75     371926       Link Pagos    8          5
# 285042 2018-12-08     1529.15     370935       Link Pagos    8          5
# 285043 2018-12-08     3544.00     374498       Link Pagos    8          5
# 285045 2018-12-08     2268.00     378970       Link Pagos    8          5
# 285048 2018-12-08     4460.00     362054       Link Pagos    8          5
# 285049 2018-12-08     1641.04     370944       Link Pagos    8          5
# 285050 2018-12-08      952.75     371920       Link Pagos    8          5
# 285051 2018-12-08     7544.00     366049       Link Pagos    8          5
# 285055 2018-12-08     2833.00     359118       Link Pagos    8          5
# 285059 2018-12-08     3000.00     379764       Link Pagos    8          5
# 285062 2018-12-08      916.00     367500       Link Pagos    8          5
# 285063 2018-12-08     4866.80     364062       Link Pagos    8          5
# 285133 2018-12-08      588.00     378535       Link Pagos    8          5
# 285143 2018-12-08      100.00     371927       Link Pagos    8          5
# 285144 2018-12-08       98.37     370936       Link Pagos    8          5
# 285145 2018-12-08      126.24     370937       Link Pagos    8          5
# 285146 2018-12-08      448.00     374499       Link Pagos    8          5
# 285147 2018-12-08      263.00     374500       Link Pagos    8          5
# 285149 2018-12-08      105.57     370945       Link Pagos    8          5
# 285150 2018-12-08      135.48     370946       Link Pagos    8          5
# 285151 2018-12-08      100.00     371921       Link Pagos    8          5
# 292591 2018-12-08      237.00     383101  Nota de crédito    8          5
#
#        day_name  month  feriados
# 4841     Jueves      7      True
# 4842     Jueves      7      True
# 4843     Jueves      7      True
# 4844     Jueves      7      True
# 4845     Jueves      7      True
# 4846     Jueves      7      True
# 4847     Jueves      7      True
# 4848     Jueves      7      True
# 4869     Jueves      7      True
# 4870     Jueves      7      True
# 7400      Lunes     12      True
# 7539     Martes     12      True
# 7677      Lunes     12      True
# 7678      Lunes     12      True
# 7679      Lunes     12      True
# 7680      Lunes     12      True
# 7681      Lunes     12      True
# 7682      Lunes     12      True
# 7683      Lunes     12      True
# 7684      Lunes     12      True
# 7685      Lunes     12      True
# 8743      Lunes      2      True
# 8744      Lunes      2      True
# 8774      Lunes      2      True
# 10296    Sabado      4      True
# 10297    Sabado      4      True
# 10298    Sabado      4      True
# 10299    Sabado      4      True
# 10300    Sabado      4      True
# 10301    Sabado      4      True
# ...         ...    ...       ...
# 285022   Sabado     12      True
# 285023   Sabado     12      True
# 285024   Sabado     12      True
# 285025   Sabado     12      True
# 285026   Sabado     12      True
# 285028   Sabado     12      True
# 285029   Sabado     12      True
# 285030   Sabado     12      True
# 285041   Sabado     12      True
# 285042   Sabado     12      True
# 285043   Sabado     12      True
# 285045   Sabado     12      True
# 285048   Sabado     12      True
# 285049   Sabado     12      True
# 285050   Sabado     12      True
# 285051   Sabado     12      True
# 285055   Sabado     12      True
# 285059   Sabado     12      True
# 285062   Sabado     12      True
# 285063   Sabado     12      True
# 285133   Sabado     12      True
# 285143   Sabado     12      True
# 285144   Sabado     12      True
# 285145   Sabado     12      True
# 285146   Sabado     12      True
# 285147   Sabado     12      True
# 285149   Sabado     12      True
# 285150   Sabado     12      True
# 285151   Sabado     12      True
# 292591   Sabado     12      True
#
# [1689 rows x 9 columns]
